# %%
import os
import numpy as np
import pandas as pd

from dekef.base_density import *
from dekef.kernel_function import *
from dekef.data_median_dist import *
from dekef.negloglik_params import *

from dekef.negloglik_grid_points import *
from dekef.scorematching_penalized_grid_points import *

from dekef.plot_density_1d import *

from IPython.display import Markdown as md

from datetime import datetime as dt

import warnings
warnings.filterwarnings('ignore')
np.random.seed(1989)

# %%
df = np.load('../data/geyser.npy').astype(np.float64)
waiting = df[:, 0].reshape(-1, 1)
# waiting = waiting[waiting != 108.0]

bw = 7.
kernel_type = 'gaussian_poly2'

# %%
# set plot parameters
font_size = 15
xlimit = (1., 210.)
plot_pts_cnt = 3000
ylimit = (-0.001, 0.0451)

# plot the histogram of waiting variable 
ax = pd.Series(waiting.flatten()).hist(grid = False, figsize = (10, 10), 
                                       bins = 'fd', density = True, color = 'tab:green', alpha = 0.3)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
# ax.set_title('Histogram of Waiting Variable', fontsize = font_size)
ax.set_xlabel('waiting', fontsize = font_size)
ax.set_ylabel('density', fontsize = font_size)
ax.tick_params(axis = 'both', labelsize = font_size)

# plt.savefig(f'../plots/histogram.pdf', bbox_inches = 'tight')

# %%
108 in waiting
# Out:
# True

# %%
base_density = BasedenGamma(waiting, 26., 3.)
base_density.a, base_density.scale
# Out:
# (26.0, 3.0)

# %%
seed_no = 1
grid_points = np.unique(waiting) # np.arange(1., 201., gap).reshape(-1, 1)
xlimit = (1., 210.)
plot_pts_cnt = 3000

new_data = np.linspace(xlimit[0], xlimit[1], plot_pts_cnt)

ml_folder = (f'../data/data=geyser-waiting-PenML-bw={bw}-kernel={kernel_type}-' + 
             f'plotdomain={xlimit}-plotcnts={plot_pts_cnt}-baseden=Gamma-{base_density.a}-{base_density.scale}-' + 
             f'grid_points=data-seed={seed_no}-with108={108 in waiting}')

if not os.path.isdir(ml_folder):
    os.mkdir(ml_folder)

file_name_newdata = f'/new_data.npy'
np.save(ml_folder + file_name_newdata, new_data)

file_name_grid_points = f'/grid_points.npy'
np.save(ml_folder + file_name_grid_points, grid_points)

# %%
nll_pen = NegLogLikGridPoints(
    data = waiting, 
    grid_points = grid_points, 
    base_density = base_density,
    kernel_type = 'gaussian_poly2', 
    kernel_r1 = 1.0, 
    kernel_r2 = 0.0, 
    kernel_c = 0.0, 
    kernel_bw = bw
)

# %%
0.05 / np.sqrt(200) * np.sqrt(len(grid_points))
# Out:
# 0.025495097567963924

# %%
# set parameters for computing the density estimate
bmc_params = batch_montecarlo_params(
    mc_batch_size = 5000, 
    mc_tol = 5e-3)

gdalgo_params = negloglik_optalgo_params(
    start_pt = np.zeros((grid_points.shape[0], 1)), 
    step_size = 0.4, 
    max_iter = 50, 
    rel_tol = 1e-5, 
    abs_tol = 0.05 / np.sqrt(200) * np.sqrt(len(grid_points))
)

ml_log_pen_param_list = [-np.inf, -15., -14., -13., -12., -11., -10., -9.5, -9., -8.5, -8., -7.5, -7., -6.5, -6.]

# %%
waiting = waiting.reshape(-1, 1)
for log_pen_param in ml_log_pen_param_list: 
    
    print('*' * 50)
    print(f'log penalty = {log_pen_param}')
    
    np.random.seed(seed_no)
    print(f'start time = {dt.now().strftime("%H:%M:%S")}')
    nll_pen_coef = nll_pen.coef(
        data = waiting, 
        lambda_param = np.exp(log_pen_param), 
        optalgo_params = gdalgo_params, 
        batchmc_params = bmc_params, 
        batch_mc = True, 
        print_error = True
    )
    print(f'end time = {dt.now().strftime("%H:%M:%S")}')
    
    plot_params = plot_density_1d_params(xlimit, ylimit, plot_pts_cnt=plot_pts_cnt)
    
    # visualize density estimate
    den_vals = plot_density_1d(
        data = waiting, 
        kernel_function = nll_pen.kernel_function, 
        base_density = base_density, 
        basis_type = 'grid_points', 
        coef = nll_pen_coef, 
        normalizing = True, 
        method = 'negative log-likelihood (smbasis)', 
        x_label = 'waiting',
        grid_points = grid_points, 
        save_plot = False, 
        save_dir = None, 
        save_filename = None, 
        plot_kwargs = plot_params)
    
    kernel_function_grid = GaussianPoly2(
        data=grid_points.reshape(-1, 1),
        r1=1.,
        r2=0.,
        c=0.,
        bw=bw)

    gram_grid = kernel_function_grid.kernel_gram_matrix(grid_points.reshape(-1, 1))
    
    # compute value of loss functional
    loss_val = nll_pen.eval_loss_function(
        new_data=waiting, 
        coef=nll_pen_coef, 
        batchmc_params=bmc_params, 
        batch_mc=True)
    print(f'loss_val={loss_val}')

    print(np.sqrt(nll_pen_coef.T @ gram_grid @ nll_pen_coef).item())
    
    file_name_coef = f'/logpenparam={log_pen_param}-coef.npy'
    np.save(ml_folder + file_name_coef, nll_pen_coef)

    file_name_den = f'/logpenparam={log_pen_param}-densityvals-newdata.npy'
    np.save(ml_folder + file_name_den, den_vals['den_vals'])
# Out:
# **************************************************
# log penalty = -inf
# start time = 13:06:11
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0.4066385879396954, Relative Error = 0.7875241742649668
# Iter = 3, GradNorm = 0.32341468848621985, Relative Error = 0.6263470635822771
# Iter = 4, GradNorm = 0.24762540953445306, Relative Error = 0.4795683487853459
# Iter = 5, GradNorm = 0.1952154709200589, Relative Error = 0.378067667702174
# Iter = 6, GradNorm = 0.17286181358779382, Relative Error = 0.334776042031359
# Iter = 7, GradNorm = 0.14357778097462537, Relative Error = 0.2780625763475417
# Iter = 8, GradNorm = 0.13209908289634506, Relative Error = 0.25583214250815617
# Iter = 9, GradNorm = 0.0888882209353881, Relative Error = 0.17214702409011096
# Iter = 10, GradNorm = 0.07132214649155504, Relative Error = 0.1381273597450535
# Iter = 11, GradNorm = 0.06683484729776486, Relative Error = 0.12943694841401293
# Iter = 12, GradNorm = 0.1041634886011959, Relative Error = 0.20173015493891183
# Iter = 13, GradNorm = 0.06570610175763643, Relative Error = 0.1272509423983302
# Iter = 14, GradNorm = 0.039268921228378904, Relative Error = 0.0760508856804346
# Iter = 15, GradNorm = 0.046421254475219, Relative Error = 0.08990258471082994
# Iter = 16, GradNorm = 0.05078247922609481, Relative Error = 0.09834883163028549
# Iter = 17, GradNorm = 0.07401780161155491, Relative Error = 0.14334795030247463
# Iter = 18, GradNorm = 0.09526443977809078, Relative Error = 0.1844956467441342
# Iter = 19, GradNorm = 0.062442501879911134, Relative Error = 0.12093043107681732
# Iter = 20, GradNorm = 0.04154352420663935, Relative Error = 0.0804560377869062
# Iter = 21, GradNorm = 0.07089232804302545, Relative Error = 0.13729494386323288
# Iter = 22, GradNorm = 0.09928678393982009, Relative Error = 0.1922855942762291
# Iter = 23, GradNorm = 0.07964646636836417, Relative Error = 0.15424880845093422
# Iter = 24, GradNorm = 0.07137717004080067, Relative Error = 0.13823392212371102
# Iter = 25, GradNorm = 0.0687466477060001, Relative Error = 0.13313947218452674
# Iter = 26, GradNorm = 0.07952795865781559, Relative Error = 0.15401929829213037
# Iter = 27, GradNorm = 0.04002019400803861, Relative Error = 0.07750585206335199
# Iter = 28, GradNorm = 0.051149389740069336, Relative Error = 0.099059415692194
# Iter = 29, GradNorm = 0.05425072002123268, Relative Error = 0.10506566458551914
# Iter = 30, GradNorm = 0.04293205074944485, Relative Error = 0.08314515350661271
# Iter = 31, GradNorm = 0.05424699501827252, Relative Error = 0.10505845048934791
# Iter = 32, GradNorm = 0.06359157136862671, Relative Error = 0.1231557978450297
# Iter = 33, GradNorm = 0.0371132781232993, Relative Error = 0.07187611942192706
# Iter = 34, GradNorm = 0.08243068457258283, Relative Error = 0.15964091635038413
# Iter = 35, GradNorm = 0.08445393253789116, Relative Error = 0.16355927710233767
# Iter = 36, GradNorm = 0.033928033365464176, Relative Error = 0.06570735599872256
# Iter = 37, GradNorm = 0.0496161578449888, Relative Error = 0.09609005366423742
# Iter = 38, GradNorm = 0.03136569469560268, Relative Error = 0.060744955220690344
# Iter = 39, GradNorm = 0.024901241370788304, Relative Error = 0.04822545161801247
# end time = 13:11:39
# loss_val=-0.2653600682648858
# 3.5948132188431345
# **************************************************
# log penalty = -14.0
# start time = 13:11:42
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0
# Iter = 28, GradNorm = 0.05417994553941855, Relative Error = 0.10492859787074399
# Iter = 29, GradNorm = 0.03958861972797132, Relative Error = 0.07667003571777095
# Iter = 30, GradNorm = 0.027002802112027848, Relative Error = 0.0522954782620598
# Iter = 31, GradNorm = 0.03555048603685903, Relative Error = 0.06884950910032075
# Iter = 32, GradNorm = 0.0419144048679235, Relative Error = 0.08117431070834365
# Iter = 33, GradNorm = 0.02629920342010284, Relative Error = 0.050932840786655414
# Iter = 34, GradNorm = 0.07868606084036676, Relative Error = 0.15238882124650335
# Iter = 35, GradNorm = 0.0691002609133939, Relative Error = 0.13382430377066062
# Iter = 36, GradNorm = 0.037510879334259416, Relative Error = 0.07264614119220371
# Iter = 37, GradNorm = 0.05605691564320631, Relative Error = 0.10856366688520923
# Iter = 38, GradNorm = 0.02740480513401332, Relative Error = 0.053074024881418214
# Iter = 39, GradNorm = 0.026572069210258422, Relative Error = 0.051461291387387136
# Iter = 40, GradNorm = 0.03476485631133723, Relative Error = 0.06732800470005139
# Iter = 41, GradNorm = 0.026158838129377332, Relative Error = 0.050660999739217824
# Iter = 42, GradNorm = 0.06611098827005549, Relative Error = 0.12803507338299497
# Iter = 43, GradNorm = 0.08352936240046092, Relative Error = 0.1617686911726576
# Iter = 44, GradNorm = 0.06996943703562647, Relative Error = 0.1355076098519161
# Iter = 45, GradNorm = 0.07074214641845816, Relative Error = 0.1370040918305314
# Iter = 46, GradNorm = 0.08989549182386523, Relative Error = 0.17409777396539514
# Iter = 47, GradNorm = 0.06206449725804644, Relative Error = 0.12019836140480065
# Iter = 48, GradNorm = 0.08106675918971855, Relative Error = 0.15699944492402132
# Iter = 49, GradNorm = 0.036840597489666664, Relative Error = 0.07134802740801462
# Iter = 50, GradNorm = 0.06358730142982673, Relative Error = 0.12314752838874259
# end time = 18:29:43
# loss_val=-0.2532969032915322
# 2.389446164074135

# %%
waiting = waiting.reshape(-1, 1)

gdalgo_params = negloglik_optalgo_params(
    start_pt = np.zeros((grid_points.shape[0], 1)), 
    step_size = 0.35, 
    max_iter = 50, 
    rel_tol = 1e-5, 
    abs_tol = 0.05 / np.sqrt(200) * np.sqrt(len(grid_points))
)

for log_pen_param in [-4.5, -4.]: 
    
    print('*' * 50)
    print(f'log penalty = {log_pen_param}')
    
    np.random.seed(seed_no)
    print(f'start time = {dt.now().strftime("%H:%M:%S")}')
    nll_pen_coef = nll_pen.coef(
        data = waiting, 
        lambda_param = np.exp(log_pen_param), 
        optalgo_params = gdalgo_params, 
        batchmc_params = bmc_params, 
        batch_mc = True, 
        print_error = True
    )
    print(f'end time = {dt.now().strftime("%H:%M:%S")}')
    
    plot_params = plot_density_1d_params(xlimit, ylimit, plot_pts_cnt=plot_pts_cnt)
    
    # visualize density estimate
    den_vals = plot_density_1d(
        data = waiting, 
        kernel_function = nll_pen.kernel_function, 
        base_density = base_density, 
        basis_type = 'grid_points', 
        coef = nll_pen_coef, 
        normalizing = True, 
        method = 'negative log-likelihood (smbasis)', 
        x_label = 'waiting',
        grid_points = grid_points, 
        save_plot = False, 
        save_dir = None, 
        save_filename = None, 
        plot_kwargs = plot_params)
    
    kernel_function_grid = GaussianPoly2(
        data=grid_points.reshape(-1, 1),
        r1=1.,
        r2=0.,
        c=0.,
        bw=bw)

    gram_grid = kernel_function_grid.kernel_gram_matrix(grid_points.reshape(-1, 1))

    # compute value of loss functional
    loss_val = nll_pen.eval_loss_function(
        new_data=waiting, 
        coef=nll_pen_coef, 
        batchmc_params=bmc_params, 
        batch_mc=True)
    print(f'loss_val={loss_val}')
    
    print(np.sqrt(nll_pen_coef.T @ gram_grid @ nll_pen_coef).item())
    
    file_name_coef = f'/logpenparam={log_pen_param}-coef.npy'
    np.save(ml_folder + file_name_coef, nll_pen_coef)

    file_name_den = f'/logpenparam={log_pen_param}-densityvals-newdata.npy'
    np.save(ml_folder + file_name_den, den_vals['den_vals'])
# Out:
# **************************************************
# log penalty = -4.5
# start time = 19:11:52
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0.40539273019432703, Relative Error = 0.7851113607217565
# Iter = 3, GradNorm = 0.32235048990918796, Relative Error = 0.6242860636415747
# Iter = 4, GradNorm = 0.2453243621361858, Relative Error = 0.4751119826016877
# Iter = 5, GradNorm = 0.19127297202315138, Relative Error = 0.3704323539852474
# Iter = 6, GradNorm = 0.16630828572012052, Relative Error = 0.32208403056077706
# Iter = 7, GradNorm = 0.1314966918972659, Relative Error = 0.25466551079093996
# Iter = 8, GradNorm = 0.11716855925122587, Relative Error = 0.2269166665703197
# Iter = 9, GradNorm = 0.07876743363965508, Relative Error = 0.15254641338966873
# Iter = 10, GradNorm = 0.060107269006014825, Relative Error = 0.11640785895681889
# Iter = 11, GradNorm = 0.05163412274823107, Relative Error = 0.0999981828759128
# Iter = 12, GradNorm = 0.0875093000217559, Relative Error = 0.16947651129055852
# Iter = 13, GradNorm = 0.05154184209157066, Relative Error = 0.0998194658281645
# Iter = 14, GradNorm = 0.03692789213981773, Relative Error = 0.07151708821364618
# Iter = 19, GradNorm = 0.05330875981229748, Relative Error = 0.10324139985085468
# Iter = 20, GradNorm = 0.04189791700396269, Relative Error = 0.0811423791803573
# Iter = 21, GradNorm = 0.04313213584855052, Relative Error = 0.08353265203018932
# Iter = 22, GradNorm = 0.036038987869928735, Relative Error = 0.0697955752488
# Iter = 23, GradNorm = 0.03390944182433758, Relative Error = 0.06567135034527925
# Iter = 24, GradNorm = 0.04455285310820817, Relative Error = 0.08628411049960001
# Iter = 25, GradNorm = 0.03449777150785662, Relative Error = 0.06681074995454017
# Iter = 26, GradNorm = 0.036810885917770396, Relative Error = 0.07129048594043703
# Iter = 27, GradNorm = 0.050485048268895764, Relative Error = 0.09777280644252404
# Iter = 28, GradNorm = 0.03968080932665189, Relative Error = 0.07684857641639127
# Iter = 29, GradNorm = 0.05504967186390626, Relative Error = 0.10661296951141638
# Iter = 30, GradNorm = 0.038714832685245365, Relative Error = 0.07497779981169841
# Iter = 31, GradNorm = 0.026802992961567594, Relative Error = 0.051908514159552804
# Iter = 32, GradNorm = 0.03844313116857182, Relative Error = 0.07445160402283098
# Iter = 33, GradNorm = 0.039111004951764346, Relative Error = 0.07574505419018182
# Iter = 34, GradNorm = 0.04624745357514999, Relative Error = 0.08956598996952209
# Iter = 35, GradNorm = 0.05313884104720548, Relative Error = 0.10291232351835707
# Iter = 36, GradNorm = 0.02219019909011539, Relative Error = 0.04297506123007179
# end time = 19:16:31
# loss_val=-0.24817548545381457
# 2.0772849796440145

# %%
waiting = waiting.reshape(-1, 1)

gdalgo_params = negloglik_optalgo_params(
    start_pt = np.zeros((grid_points.shape[0], 1)), 
    step_size = 0.3, 
    max_iter = 50, 
    rel_tol = 1e-5, 
    abs_tol = 0.05 / np.sqrt(200) * np.sqrt(len(grid_points))
)

for log_pen_param in [-3.5, -3., -2.5, -2., -1.5]: 
    
    print('*' * 50)
    print(f'log penalty = {log_pen_param}')
    
    np.random.seed(seed_no)
    print(f'start time = {dt.now().strftime("%H:%M:%S")}')
    nll_pen_coef = nll_pen.coef(
        data = waiting, 
        lambda_param = np.exp(log_pen_param), 
        optalgo_params = gdalgo_params, 
        batchmc_params = bmc_params, 
        batch_mc = True, 
        print_error = True
    )
    print(f'end time = {dt.now().strftime("%H:%M:%S")}')
    
    plot_params = plot_density_1d_params(xlimit, ylimit, plot_pts_cnt=plot_pts_cnt)
    
    # visualize density estimate
    den_vals = plot_density_1d(
        data = waiting, 
        kernel_function = nll_pen.kernel_function, 
        base_density = base_density, 
        basis_type = 'grid_points', 
        coef = nll_pen_coef, 
        normalizing = True, 
        method = 'negative log-likelihood (smbasis)', 
        x_label = 'waiting',
        grid_points = grid_points, 
        save_plot = False, 
        save_dir = None, 
        save_filename = None, 
        plot_kwargs = plot_params)
    
    kernel_function_grid = GaussianPoly2(
        data=grid_points.reshape(-1, 1),
        r1=1.,
        r2=0.,
        c=0.,
        bw=bw)

    gram_grid = kernel_function_grid.kernel_gram_matrix(grid_points.reshape(-1, 1))

    # compute value of loss functional
    loss_val = nll_pen.eval_loss_function(
        new_data=waiting, 
        coef=nll_pen_coef, 
        batchmc_params=bmc_params, 
        batch_mc=True)
    print(f'loss_val={loss_val}')
    
    print(np.sqrt(nll_pen_coef.T @ gram_grid @ nll_pen_coef).item())
    
    file_name_coef = f'/logpenparam={log_pen_param}-coef.npy'
    np.save(ml_folder + file_name_coef, nll_pen_coef)

    file_name_den = f'/logpenparam={log_pen_param}-densityvals-newdata.npy'
    np.save(ml_folder + file_name_den, den_vals['den_vals'])
# Out:
# **************************************************
# log penalty = -3.5
# start time = 18:34:25
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0.39940229015791523, Relative Error = 0.773509863758417
# Iter = 3, GradNorm = 0.31398501668541234, Relative Error = 0.6080849145419064
# Iter = 4, GradNorm = 0.24187229944820146, Relative Error = 0.4684264812781661
# Iter = 5, GradNorm = 0.17541471158382413, Relative Error = 0.3397201593530644
# Iter = 6, GradNorm = 0.17665467181160627, Relative Error = 0.3421215513593005
# Iter = 7, GradNorm = 0.12171176772596853, Relative Error = 0.23571535564877952
# Iter = 8, GradNorm = 0.09521695508296492, Relative Error = 0.1844036846273349
# Iter = 9, GradNorm = 0.09331324130486775, Relative Error = 0.1807168219792796
# Iter = 10, GradNorm = 0.08381756431061166, Relative Error = 0.16232684275503204
# Iter = 11, GradNorm = 0.047847409756790624, Relative Error = 0.0926645748263865
# Iter = 12, GradNorm = 0.04327901023033998, Relative Error = 0.0838170990297362
# Iter = 13, GradNorm = 0.07581294117627382, Relative Error = 0.14682454068352643
# Iter = 14, GradNorm = 0.048649036849035376, Relative Error = 0.094217060824056
# Iter = 15, GradNorm = 0.04368864220376399, Relative Error = 0.08461042039959871
# Iter = 16, GradNorm = 0.03771654928327903, Relative Error = 0.07304445571909952
# Iter = 17, GradNorm = 0.04254107168799556, Relative Error = 0.08238795664518646
# Iter = 18, GradNorm = 0.08288746274099094, Relative Error = 0.1605255442744591
# Iter = 19, GradNorm = 0.06741060201857729, Relative Error = 0.13055199448817995
# Iter = 23, GradNorm = 1.368576077983992, Relative Error = 2.6504782814487005
# Iter = 24, GradNorm = 1.5246521614494057, Relative Error = 2.95274592745931
# Iter = 25, GradNorm = 1.6987095995223238, Relative Error = 3.2898374978573917
# Iter = 26, GradNorm = 1.918213014194976, Relative Error = 3.714942862953871
# Iter = 27, GradNorm = 2.1625831005895075, Relative Error = 4.188206729715705
# Iter = 28, GradNorm = 2.431887507650019, Relative Error = 4.709760111727
# Iter = 29, GradNorm = 2.7141062515938983, Relative Error = 5.256324284135203
# Iter = 30, GradNorm = 2.9903597093186596, Relative Error = 5.791335674187536
# Iter = 31, GradNorm = 3.248130280628944, Relative Error = 6.29055183896294
# Iter = 32, GradNorm = 3.613117776589878, Relative Error = 6.997411652317149
# Iter = 33, GradNorm = 3.9675144845036208, Relative Error = 7.68376061928578
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-0062832629b5> in <module>
#      16     np.random.seed(seed_no)
#      17     print(f'start time = {dt.now().strftime("%H:%M:%S")}')
# ---> 18     nll_pen_coef = nll_pen.coef(
#      19         data = waiting,
#      20         lambda_param = np.exp(log_pen_param),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dekef/negloglik_grid_points.py in coef(self, data, lambda_param, optalgo_params, batchmc_params, batch_mc, print_error)
#     559                         if batch_mc:
#     560
# --> 561 				mc_output1, mc_output2 = self.grad_logpar_batchmc(
#     562                                         coef=current_iter,
#     563                                         batch_size=mc_batch_size,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dekef/negloglik_grid_points.py in grad_logpar_batchmc(self, coef, batch_size, tol_param, compute_grad, print_error)
#     247
#     248                         mc_samples1 = self.base_density.sample(batch_size)
# --> 249                         mc_kernel_matrix1 = self.kernel_function.kernel_gram_matrix(mc_samples1)
#     250                         density_part1 = np.exp(np.matmul(mc_kernel_matrix1.T, coef).flatten()) / normalizing_const
#     251 			exp_est1 = np.array([np.mean(mc_kernel_matrix1[l1, :] * density_part1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dekef/kernel_function.py in kernel_gram_matrix(self, new_data)
#     318
#     319         gauss_part = self.r1 * self.gaussian_kernel_gram_matrix(new_data=new_data)
# --> 320         poly_part = self.r2 * (self.poly_kernel_gram_matrix(new_data=new_data) + self.c) ** 2
#     321
#     322         output = gauss_part + poly_part
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dekef/kernel_function.py in poly_kernel_gram_matrix(self, new_data)
#     288
#     289         prod_entry = tiled_data * tiled_land
# --> 290         split_prod = np.sum(np.vstack(np.split(prod_entry, self.N * n, axis=1)), axis=1)
#     291         split_prod = split_prod.reshape(n, self.N)
#     292         poly_part = split_prod
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/shape_base.py in vstack(tup)
#     278         # raise warning if necessary
#     279         _arrays_for_stack_dispatcher(tup, stacklevel=2)
# --> 280     arrs = atleast_2d(*tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
#
# <__array_function__ internals> in atleast_2d(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/shape_base.py in atleast_2d(*arys)
#     120     res = []
#     121     for ary in arys:
# --> 122         ary = asanyarray(ary)
#     123         if ary.ndim == 0:
#     124             result = ary.reshape(1, 1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asanyarray(a, dtype, order, like)
#     169         return _asanyarray_with_like(a, dtype=dtype, order=order, like=like)
#     170
# --> 171     return array(a, dtype, copy=False, order=order, subok=True)
#     172
#     173
#
# KeyboardInterrupt:

# %%
waiting = waiting.reshape(-1, 1)

gdalgo_params = negloglik_optalgo_params(
    start_pt = np.zeros((grid_points.shape[0], 1)), 
    step_size = 0.1, 
    max_iter = 50, 
    rel_tol = 1e-5, 
    abs_tol = 0.05 / np.sqrt(200) * np.sqrt(len(grid_points))
)

for log_pen_param in [-0.5, 0.]: 
    
    print('*' * 50)
    print(f'log penalty = {log_pen_param}')
    
    np.random.seed(seed_no)
    print(f'start time = {dt.now().strftime("%H:%M:%S")}')
    nll_pen_coef = nll_pen.coef(
        data = waiting, 
        lambda_param = np.exp(log_pen_param), 
        optalgo_params = gdalgo_params, 
        batchmc_params = bmc_params, 
        batch_mc = True, 
        print_error = True
    )
    print(f'end time = {dt.now().strftime("%H:%M:%S")}')
    
    plot_params = plot_density_1d_params(xlimit, ylimit, plot_pts_cnt=plot_pts_cnt)
    
    # visualize density estimate
    den_vals = plot_density_1d(
        data = waiting, 
        kernel_function = nll_pen.kernel_function, 
        base_density = base_density, 
        basis_type = 'grid_points', 
        coef = nll_pen_coef, 
        normalizing = True, 
        method = 'negative log-likelihood (smbasis)', 
        x_label = 'waiting',
        grid_points = grid_points, 
        save_plot = False, 
        save_dir = None, 
        save_filename = None, 
        plot_kwargs = plot_params)
    
    kernel_function_grid = GaussianPoly2(
        data=grid_points.reshape(-1, 1),
        r1=1.,
        r2=0.,
        c=0.,
        bw=bw)

    gram_grid = kernel_function_grid.kernel_gram_matrix(grid_points.reshape(-1, 1))

    # compute value of loss functional
    loss_val = nll_pen.eval_loss_function(
        new_data=waiting, 
        coef=nll_pen_coef, 
        batchmc_params=bmc_params, 
        batch_mc=True)
    print(f'loss_val={loss_val}')
    
    print(np.sqrt(nll_pen_coef.T @ gram_grid @ nll_pen_coef).item())
    
    file_name_coef = f'/logpenparam={log_pen_param}-coef.npy'
    np.save(ml_folder + file_name_coef, nll_pen_coef)

    file_name_den = f'/logpenparam={log_pen_param}-densityvals-newdata.npy'
    np.save(ml_folder + file_name_den, den_vals['den_vals'])
# Out:
# **************************************************
# log penalty = -0.5
# start time = 19:19:38
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0.2742357457189654, Relative Error = 0.5311037506191951
# Iter = 3, GradNorm = 0.16984020980187056, Relative Error = 0.32892419693588565
# Iter = 4, GradNorm = 0.1059151510386456, Relative Error = 0.20512254453389075
# Iter = 5, GradNorm = 0.07379928921907832, Relative Error = 0.14292476421892145
# Iter = 6, GradNorm = 0.0715277857684804, Relative Error = 0.1385256148702683
# Iter = 7, GradNorm = 0.053242941466089835, Relative Error = 0.10311393152815738
# Iter = 8, GradNorm = 0.05332513146281605, Relative Error = 0.10327310631191955
# Iter = 9, GradNorm = 0.05870027534438843, Relative Error = 0.11368297854843844
# Iter = 10, GradNorm = 0.044620222761070326, Relative Error = 0.08641458318914383
# Iter = 11, GradNorm = 0.058685490132471846, Relative Error = 0.1136543444931587
# Iter = 12, GradNorm = 0.03453801115585952, Relative Error = 0.06688868081625882
# Iter = 13, GradNorm = 0.0370734412312545, Relative Error = 0.07179896856501548
# Iter = 14, GradNorm = 0.027162539254556018, Relative Error = 0.05260483616610504
# Iter = 15, GradNorm = 0.03121766576171127, Relative Error = 0.06045827223637051
# Iter = 16, GradNorm = 0.023978845875603668, Relative Error = 0.04643907724962928
# end time = 19:20:34
# loss_val=-0.05761166668767028
# 0.29646040926303285
# **************************************************
# log penalty = 0.0
# start time = 19:20:36
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0.19508145510568936, Relative Error = 0.3778081234860568
# Iter = 3, GradNorm = 0.12380738646050089, Relative Error = 0.23977387459517016
# Iter = 4, GradNorm = 0.0804942451264587, Relative Error = 0.1558906749294957
# Iter = 5, GradNorm = 0.051861356944080464, Relative Error = 0.10043826020196725
# Iter = 6, GradNorm = 0.0479215893156105, Relative Error = 0.09280823604679095
# Iter = 7, GradNorm = 0.03438559543666427, Relative Error = 0.06659350208269987
# Iter = 8, GradNorm = 0.04170506179625553, Relative Error = 0.08076888256024606
# Iter = 9, GradNorm = 0.061389468446638784, Relative Error = 0.118891054319159
# Iter = 10, GradNorm = 0.0634195707733942, Relative Error = 0.12282268969752243
# Iter = 11, GradNorm = 0.0718657354724516, Relative Error = 0.1391801114415639
# Iter = 12, GradNorm = 0.06481379473456511, Relative Error = 0.1255228394283305
# Iter = 13, GradNorm = 0.036291012799937315, Relative Error = 0.07028366401062854
# Iter = 14, GradNorm = 0.01908616863344005, Relative Error = 0.03696358299168809
# end time = 19:21:25
# loss_val=-0.03860565376546747
# 0.19124110413111534

# %%
waiting = waiting.reshape(-1, 1)

gdalgo_params = negloglik_optalgo_params(
    start_pt = np.zeros((grid_points.shape[0], 1)), 
    step_size = 0.05, 
    max_iter = 50, 
    rel_tol = 1e-5, 
    abs_tol = 0.05 / np.sqrt(200) * np.sqrt(len(grid_points))
)

for log_pen_param in [0.5, 1.]: 
    
    print('*' * 50)
    print(f'log penalty = {log_pen_param}')
    
    np.random.seed(seed_no)
    print(f'start time = {dt.now().strftime("%H:%M:%S")}')
    nll_pen_coef = nll_pen.coef(
        data = waiting, 
        lambda_param = np.exp(log_pen_param), 
        optalgo_params = gdalgo_params, 
        batchmc_params = bmc_params, 
        batch_mc = True, 
        print_error = True
    )
    print(f'end time = {dt.now().strftime("%H:%M:%S")}')
    
    plot_params = plot_density_1d_params(xlimit, ylimit, plot_pts_cnt=plot_pts_cnt)
    
    # visualize density estimate
    den_vals = plot_density_1d(
        data = waiting, 
        kernel_function = nll_pen.kernel_function, 
        base_density = base_density, 
        basis_type = 'grid_points', 
        coef = nll_pen_coef, 
        normalizing = True, 
        method = 'negative log-likelihood (smbasis)', 
        x_label = 'waiting',
        grid_points = grid_points, 
        save_plot = False, 
        save_dir = None, 
        save_filename = None, 
        plot_kwargs = plot_params)
    
    kernel_function_grid = GaussianPoly2(
        data=grid_points.reshape(-1, 1),
        r1=1.,
        r2=0.,
        c=0.,
        bw=bw)

    gram_grid = kernel_function_grid.kernel_gram_matrix(grid_points.reshape(-1, 1))

    # compute value of loss functional
    loss_val = nll_pen.eval_loss_function(
        new_data=waiting, 
        coef=nll_pen_coef, 
        batchmc_params=bmc_params, 
        batch_mc=True)
    print(f'loss_val={loss_val}')
    
    print(np.sqrt(nll_pen_coef.T @ gram_grid @ nll_pen_coef).item())
    
    file_name_coef = f'/logpenparam={log_pen_param}-coef.npy'
    np.save(ml_folder + file_name_coef, nll_pen_coef)

    file_name_den = f'/logpenparam={log_pen_param}-densityvals-newdata.npy'
    np.save(ml_folder + file_name_den, den_vals['den_vals'])
# Out:
# **************************************************
# log penalty = 0.5
# start time = 19:21:27
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0.23034872015005387, Relative Error = 0.4461091273906979
# Iter = 3, GradNorm = 0.13423500746361933, Relative Error = 0.2599687204941696
# Iter = 4, GradNorm = 0.07811575966249774, Relative Error = 0.15128433687757217
# Iter = 5, GradNorm = 0.05580459480864201, Relative Error = 0.1080750050543267
# Iter = 6, GradNorm = 0.056392685237139945, Relative Error = 0.10921394130590706
# Iter = 7, GradNorm = 0.04268268232423488, Relative Error = 0.08266220951414449
# Iter = 8, GradNorm = 0.047650998387441086, Relative Error = 0.09228419109977819
# Iter = 9, GradNorm = 0.05644701654867181, Relative Error = 0.10931916304953856
# Iter = 10, GradNorm = 0.04652393173166146, Relative Error = 0.09010143652665327
# Iter = 11, GradNorm = 0.05883783926594339, Relative Error = 0.11394939427223906
# Iter = 12, GradNorm = 0.04073722653890287, Relative Error = 0.07889450643245907
# Iter = 13, GradNorm = 0.03063327872808419, Relative Error = 0.05932650823325389
# Iter = 14, GradNorm = 0.02110124659501418, Relative Error = 0.04086612115415963
# end time = 19:22:16
# loss_val=-0.024367389509068586
# 0.11900223418901486
# **************************************************
# log penalty = 1.0
# start time = 19:22:19
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0.22698109457829727, Relative Error = 0.4395871527766593
# Iter = 3, GradNorm = 0.22477654485720605, Relative Error = 0.4353176706118582
# Iter = 4, GradNorm = 0.24331063526185923, Relative Error = 0.4712120610474293
# Iter = 5, GradNorm = 0.26861316928347684, Relative Error = 0.5202146835313062
# Iter = 6, GradNorm = 0.30245708766506285, Relative Error = 0.5857591366841439
# Iter = 7, GradNorm = 0.3461176370032239, Relative Error = 0.6703151505137739
# Iter = 8, GradNorm = 0.42551741273170657, Relative Error = 0.8240862009549337
# Iter = 9, GradNorm = 0.5238402500356245, Relative Error = 1.0145049500743355
# Iter = 10, GradNorm = 0.6374658707558487, Relative Error = 1.2345601189318203
# Iter = 11, GradNorm = 0.7952252178506513, Relative Error = 1.5400876887153336
# Iter = 12, GradNorm = 0.9634583591511346, Relative Error = 1.8658995265882132
# Iter = 13, GradNorm = 1.1332532435039353, Relative Error = 2.19473594315128
# Iter = 14, GradNorm = 1.3468557695452228, Relative Error = 2.608413242676338
# Iter = 15, GradNorm = 1.6171608483096735, Relative Error = 3.1319045941296086
# Iter = 16, GradNorm = 1.9343284930453204, Relative Error = 3.746153204399342
# Iter = 17, GradNorm = 2.3027384366662527, Relative Error = 4.4596411645830525
# Iter = 18, GradNorm = 2.7292896903832045, Relative Error = 5.285729572884691
# Iter = 19, GradNorm = 3.250058371776617, Relative Error = 6.294285912496571
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-dec87b29bda3> in <module>
#      16     np.random.seed(seed_no)
#      17     print(f'start time = {dt.now().strftime("%H:%M:%S")}')
# ---> 18     nll_pen_coef = nll_pen.coef(
#      19         data = waiting,
#      20         lambda_param = np.exp(log_pen_param),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dekef/negloglik_grid_points.py in coef(self, data, lambda_param, optalgo_params, batchmc_params, batch_mc, print_error)
#     559                         if batch_mc:
#     560
# --> 561 				mc_output1, mc_output2 = self.grad_logpar_batchmc(
#     562                                         coef=current_iter,
#     563                                         batch_size=mc_batch_size,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dekef/negloglik_grid_points.py in grad_logpar_batchmc(self, coef, batch_size, tol_param, compute_grad, print_error)
#     253
#     254                         mc_samples2 = self.base_density.sample(batch_size)
# --> 255                         mc_kernel_matrix2 = self.kernel_function.kernel_gram_matrix(mc_samples2)
#     256                         density_part2 = np.exp(np.matmul(mc_kernel_matrix2.T, coef).flatten()) / normalizing_const
#     257 			exp_est2 = np.array([np.mean(mc_kernel_matrix2[l1, :] * density_part2)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dekef/kernel_function.py in kernel_gram_matrix(self, new_data)
#     317         """
#     318
# --> 319         gauss_part = self.r1 * self.gaussian_kernel_gram_matrix(new_data=new_data)
#     320         poly_part = self.r2 * (self.poly_kernel_gram_matrix(new_data=new_data) + self.c) ** 2
#     321
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dekef/kernel_function.py in gaussian_kernel_gram_matrix(self, new_data)
#     252
#     253         diff = - (tiled_data - tiled_land) ** 2 / (2 * bw ** 2)
# --> 254         power = np.sum(np.vstack(np.split(diff, self.N * n, axis=1)), axis=1)
#     255         power = power.reshape(n, self.N)
#     256
#
# <__array_function__ internals> in split(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/shape_base.py in split(ary, indices_or_sections, axis)
#     872             raise ValueError(
#     873                 'array split does not result in an equal division') from None
# --> 874     return array_split(ary, indices_or_sections, axis)
#     875
#     876
#
# <__array_function__ internals> in array_split(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/shape_base.py in array_split(ary, indices_or_sections, axis)
#     788         st = div_points[i]
#     789         end = div_points[i + 1]
# --> 790         sub_arys.append(_nx.swapaxes(sary[st:end], axis, 0))
#     791
#     792     return sub_arys
#
# <__array_function__ internals> in swapaxes(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _swapaxes_dispatcher(a, axis1, axis2)
#     545
#     546
# --> 547 def _swapaxes_dispatcher(a, axis1, axis2):
#     548     return (a,)
#     549
#
# KeyboardInterrupt:

# %%
waiting = waiting.reshape(-1, 1)

gdalgo_params = negloglik_optalgo_params(
    start_pt = np.zeros((grid_points.shape[0], 1)), 
    step_size = 0.02, 
    max_iter = 50, 
    rel_tol = 1e-5, 
    abs_tol = 0.05 / np.sqrt(200) * np.sqrt(len(grid_points))
)

for log_pen_param in [1.]: 
    
    print('*' * 50)
    print(f'log penalty = {log_pen_param}')
    
    np.random.seed(seed_no)
    print(f'start time = {dt.now().strftime("%H:%M:%S")}')
    nll_pen_coef = nll_pen.coef(
        data = waiting, 
        lambda_param = np.exp(log_pen_param), 
        optalgo_params = gdalgo_params, 
        batchmc_params = bmc_params, 
        batch_mc = True, 
        print_error = True
    )
    print(f'end time = {dt.now().strftime("%H:%M:%S")}')
    
    plot_params = plot_density_1d_params(xlimit, ylimit, plot_pts_cnt=plot_pts_cnt)
    
    # visualize density estimate
    den_vals = plot_density_1d(
        data = waiting, 
        kernel_function = nll_pen.kernel_function, 
        base_density = base_density, 
        basis_type = 'grid_points', 
        coef = nll_pen_coef, 
        normalizing = True, 
        method = 'negative log-likelihood (smbasis)', 
        x_label = 'waiting',
        grid_points = grid_points, 
        save_plot = False, 
        save_dir = None, 
        save_filename = None, 
        plot_kwargs = plot_params)
    
    kernel_function_grid = GaussianPoly2(
        data=grid_points.reshape(-1, 1),
        r1=1.,
        r2=0.,
        c=0.,
        bw=bw)

    gram_grid = kernel_function_grid.kernel_gram_matrix(grid_points.reshape(-1, 1))

    # compute value of loss functional
    loss_val = nll_pen.eval_loss_function(
        new_data=waiting, 
        coef=nll_pen_coef, 
        batchmc_params=bmc_params, 
        batch_mc=True)
    print(f'loss_val={loss_val}')
    
    print(np.sqrt(nll_pen_coef.T @ gram_grid @ nll_pen_coef).item())
    
    file_name_coef = f'/logpenparam={log_pen_param}-coef.npy'
    np.save(ml_folder + file_name_coef, nll_pen_coef)

    file_name_den = f'/logpenparam={log_pen_param}-densityvals-newdata.npy'
    np.save(ml_folder + file_name_den, den_vals['den_vals'])
# Out:
# **************************************************
# log penalty = 1.0
# start time = 19:23:39
# Iter = 1, GradNorm = 0.5163506102136233, Relative Error = 1.0
# Iter = 2, GradNorm = 0.31545090984812807, Relative Error = 0.6109238637630747
# Iter = 3, GradNorm = 0.21040586360400984, Relative Error = 0.4074864238408884
# Iter = 4, GradNorm = 0.14358260915243945, Relative Error = 0.2780719269277842
# Iter = 5, GradNorm = 0.10256474369374141, Relative Error = 0.1986339159186983
# Iter = 6, GradNorm = 0.09522970392576233, Relative Error = 0.18442837491053635
# Iter = 7, GradNorm = 0.07172425315570667, Relative Error = 0.13890610708493806
# Iter = 8, GradNorm = 0.061716262746092244, Relative Error = 0.1195239465690941
# Iter = 9, GradNorm = 0.06364450752347571, Relative Error = 0.12325831763255758
# Iter = 10, GradNorm = 0.04186741241514404, Relative Error = 0.08108330190182744
# Iter = 11, GradNorm = 0.06422464127550719, Relative Error = 0.12438184443887135
# Iter = 12, GradNorm = 0.03772927138830693, Relative Error = 0.07306909422010302
# Iter = 13, GradNorm = 0.040289608918013184, Relative Error = 0.07802761945288429
# Iter = 14, GradNorm = 0.03306339634748709, Relative Error = 0.06403284065803308
# Iter = 15, GradNorm = 0.036996075719392105, Relative Error = 0.07164913720947513
# Iter = 16, GradNorm = 0.028412898706169813, Relative Error = 0.0550263680223306
# Iter = 17, GradNorm = 0.02371698023426988, Relative Error = 0.04593193029143076
# end time = 19:24:38
# loss_val=-0.014862425887403972
# 0.07298064699718637

# %%
plot_params = plot_density_1d_params((1., 310.), ylimit, plot_pts_cnt=plot_pts_cnt)
    
# visualize density estimate
den_vals = plot_density_1d(
    data = waiting, 
    kernel_function = nll_pen.kernel_function, 
    base_density = base_density, 
    basis_type = 'grid_points', 
    coef = nll_pen_coef, 
    normalizing = True, 
    method = 'negative log-likelihood (smbasis)', 
    x_label = 'waiting',
    grid_points = grid_points, 
    save_plot = False, 
    save_dir = None, 
    save_filename = None, 
    plot_kwargs = plot_params)

kernel_function_grid = GaussianPoly2(
    data=grid_points.reshape(-1, 1),
    r1=1.,
    r2=0.,
    c=0.,
    bw=bw)

gram_grid = kernel_function_grid.kernel_gram_matrix(grid_points.reshape(-1, 1))

print(np.sqrt(nll_pen_coef.T @ gram_grid @ nll_pen_coef).item())

file_name_coef = f'/logpenparam={log_pen_param}-coef.npy'
np.save(ml_folder + file_name_coef, nll_pen_coef)

file_name_den = f'/logpenparam={log_pen_param}-densityvals-newdata.npy'
np.save(ml_folder + file_name_den, den_vals['den_vals'])

# %%
ml_folder

# %%
from matplotlib import gridspec

# %%
ml_folder = (f'../data/PenML-ContamData={contam_pt}-bw={bw}-' + 
             f'kernel={kernel_type}-plotdomain={xlimit}-plotcnts={plot_pts_cnt}-' + 
             f'seed={seed_no}')

sm_folder = (f'../data/PenSM-FinKEF-ContamData={contam_pt}-bw={bw}-kernel={kernel_type}-' + 
             f'plotdomain={xlimit}-plotcnts={plot_pts_cnt}')

new_data = np.linspace(xlimit[0], xlimit[1], plot_pts_cnt)

# %%
fig = plt.figure(constrained_layout=False)

fig.set_figheight(20)
fig.set_figwidth(50)
ncols = 5
nrows = 2
linewidth = 4.0
var_name = 'waiting'

label_fontsize = 35
tick_fontsize = 30
info_fontsize = 40

spec = gridspec.GridSpec(ncols=ncols, nrows=nrows, figure=fig)
ml_logpen_list1 = [-np.inf, -20., -15., -10., -9.]
ml_logpen_list2 = [-6., -4.5, -3., -2., 1.]

for i in range(ncols): 
    
    ax = fig.add_subplot(spec[0, i])
    file_name_den = f'/logpenparam={ml_logpen_list1[i]}-densityvals-newdata.npy'
    sm_den = np.load(ml_folder + file_name_den)

    ax.plot(new_data.flatten(), sm_den.flatten(), color = 'tab:red', linewidth = linewidth)
    plt.hist(waiting, bins='fd', density = True, alpha = 0.3, color = 'tab:green')
    
    if i == 0: 
        ax.set_ylabel(r'density', fontsize = label_fontsize)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    # ax.axvline(108., 0, 1, ls = '--', color = 'tab:purple', alpha = 0.5)
    # ax.tick_params(axis = 'both', labelsize = fontsize)
    # ax.ticklabel_format(axis = 'y', style = 'sci', scilimits = scilimits)
    ax.tick_params(axis = 'both', labelsize = tick_fontsize)
    ax.set_xticks([])
    if i != 0: 
        ax.set_yticks([])
    #ax.set_xlabel(var_name, fontsize = fontsize)

    if i == 0: 
        info = r"$\lambda$=0"
    else: 
        info = r"$\lambda$=exp({bw})".format(bw = ml_logpen_list1[i])

    ax.text(0.02, 0.978,
            info,
            fontsize = info_fontsize,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})

for i in range(ncols): 
    
    ax = fig.add_subplot(spec[1, i])
    file_name_den = f'/logpenparam={ml_logpen_list2[i]}-densityvals-newdata.npy'
    ml_den = np.load(ml_folder + file_name_den)

    ax.plot(new_data.flatten(), ml_den.flatten(), color = 'tab:red', linewidth = linewidth)
    plt.hist(waiting, bins='fd', density = True, alpha = 0.3, color = 'tab:green')
    
    if i == 0: 
        ax.set_ylabel(r'density', fontsize = label_fontsize)
    ax.set_xlim(xlimit)
    ax.set_ylim(ylimit)
    # ax.axvline(108., 0, 1, ls = '--', color = 'tab:purple', alpha = 0.5)
    # ax.tick_params(axis = 'both', labelsize = fontsize)
    # ax.ticklabel_format(axis = 'y', style = 'sci', scilimits = scilimits)
    ax.tick_params(axis = 'both', labelsize = tick_fontsize)
    ax.set_xlabel(var_name, fontsize = label_fontsize)
    if i != 0: 
        ax.set_yticks([])
    #ax.set_xlabel(var_name, fontsize = fontsize)

    info = r"$\lambda$=exp({bw})".format(bw = ml_logpen_list2[i])

    ax.text(0.015, 0.988,
            info,
            fontsize = info_fontsize,
            multialignment = 'left',
            horizontalalignment = 'left',
            verticalalignment = 'top',
            transform = ax.transAxes,
            bbox = {'facecolor': 'none',
                    'boxstyle': 'Round, pad=0.2'})


plt.tight_layout()

# plt.savefig('../plots/ML-only-density-comparison.pdf')
