# %%
import os
import copy
import numpy as np
import pandas as pd 
from dekef.base_density import *
from dekef.kernel_function import *
from dekef.ortho_proj_hatz import hatz
from IFlogdensity.influence_function_sm_de import plot_IF_1d_params
from IFlogdensity.contam_sm_de_finkernelexpfam import *
import seaborn as sns

import matplotlib.pyplot as plt 

from datetime import datetime as dt

import matplotlib.gridspec as gridspec

# %%
os.chdir('../')
true_data = np.load('data/geyser.npy').astype(np.float64)
df = copy.deepcopy(true_data[:, 0]).reshape(-1, 1)

# # original data with 108.0 removed
data_waiting = df[df != 108.0]
# data_waiting = df

# array of contaminated data
contam_data_list = np.arange(20., 182., 2).reshape(-1, 1)

# kernel function used
kernel_type = 'gaussian_poly2'

# bandwidth parameter in the Gaussian kernel function
bw = 5.0

k_folds = 10

seed_num = 893371436
# 893371436, 1405289136,  221902869, 2241142843,  354926085, 
# 2368900135, 2773632455, 2723165907,  572329693, 3793478080,
# 1238921510,  234059118, 2664351965,  655848720, 3958505628,
# 3332268999, 1191655600,  818578564,  401340103, 1
# 170, 644, 429, 948, 111, 362, 259, 652, 29, 178

# seed_num_list = [893371436, 1405289136,  221902869, 2241142843,  354926085, 
#                  2368900135, 2773632455, 2723165907,  572329693, 3793478080,
#                  1238921510,  234059118, 2664351965,  655848720, 3958505628,
#                  3332268999, 1191655600,  818578564,  401340103, 1, 
#                  170, 644, 429, 948, 111, 362, 259, 652, 29, 178]

# base density
base_density = BasedenGamma(data_waiting, a = 36., scale = 2.)
# base_density = BasedenUniform(data_waiting, domain = [[0., 310.]])

# penalty parameter
log_pen_param_list = np.arange(-10., -5., 0.5)

# %%
plot_kwargs = plot_IF_1d_params(x_limit=(1., 210.), plot_pts_cnt=3000)
plot_xlimit = plot_kwargs['x_limit']
plot_pts_cnt = plot_kwargs['plot_pts_cnt']

new_data = np.linspace(plot_xlimit[0], plot_xlimit[1], plot_pts_cnt)

# %%
full_save_folder = (f'data/PenSM-FinKEF-data=waiting-bw={bw}-kernel={kernel_type}-' +
                    f'empirical-inf-fun-plotdomain={plot_xlimit}-plotcnts={plot_pts_cnt}' + 
                    f'-baseden=gamma-{base_density.a}-{base_density.scale}-grid_points=1-202-1-cross-validation')
if not os.path.isdir(full_save_folder):
    os.mkdir(full_save_folder)

# %%
# compute the cross-validated density estimator under F_{n}
r1, r2, c = 1., 0., 0.

N = data_waiting.shape[0]

j = 0
sm_scores_uncontam = np.zeros((len(log_pen_param_list),), dtype = np.float64)

for log_pen_param in log_pen_param_list:

    print('*' * 50)
    print(f'log penalty = {log_pen_param}')

    grid_points = np.arange(1., 202., 1).reshape(-1, 1)
    # print(grid_points.flatten())

    # cross validation 
    np.random.seed(seed_num)
    folds_i = np.random.randint(low = 0, high = k_folds, size = N)

    score_uncontam = 0.

    for i in range(k_folds):

        # data split
        train_data = data_waiting[folds_i != i, ]
        test_data = data_waiting[folds_i == i, ]

        # ------------------------------------------------------------
        # uncontaminated data 
        uncontam_sm = ContamSMFinKernelExpFam(
            data = train_data,
            contam_data = contam_data_list[0].reshape(-1, 1),
            grid_points = grid_points,
            contam_weight = 0.,
            penalty_param = np.exp(log_pen_param),
            base_density = base_density,
            r1 = r1,
            r2 = r2,
            c = c,
            bw = bw,
            kernel_type = 'gaussian_poly2')

        coef_uncontam = uncontam_sm.coef()

        # evaluate the score matching loss function
        kernel_function_test = GaussianPoly2(
            data=test_data,
            r1=r1,
            r2=r2,
            c=c,
            bw=bw)

        matg = kernel_function_test.partial_kernel_matrix_10(grid_points).T

        t_vec = hatz(
            data=test_data,
            new_data=grid_points,
            kernel_function=kernel_function_test,
            base_density=base_density
        ).reshape(-1, 1)

        loss1 = coef_uncontam.T @ (matg @ matg.T / len(test_data)) @ coef_uncontam / 2. - coef_uncontam.T @ t_vec

        score_uncontam += loss1.item()

    sm_scores_uncontam[j, ] = score_uncontam / k_folds
    j += 1

print(f'scores with no contamination: {sm_scores_uncontam}')

print('-' * 50)

# find the optimal regularization parameter
opt_loglambda_uncontam = log_pen_param_list[np.argmin(sm_scores_uncontam)]

print("The optimal penalty parameter without contamination is {}.".format(opt_loglambda_uncontam))

# run with all data 
# uncontaminated data 
uncontam_sm = ContamSMFinKernelExpFam(
    data = data_waiting,
    contam_data = contam_data_list[0].reshape(-1, 1),
    grid_points = grid_points,
    contam_weight = 0.,
    penalty_param = np.exp(opt_loglambda_uncontam),
    base_density = base_density,
    r1 = r1,
    r2 = r2,
    c = c,
    bw = bw,
    kernel_type = 'gaussian_poly2')

coef_uncontam = uncontam_sm.coef()

gram_mat = uncontam_sm.gram_matrix
uncontam_norm = np.sqrt(coef_uncontam.T @ gram_mat @ coef_uncontam).item()
uncontam_logden_vals = uncontam_sm.log_density(new_data, coef_uncontam, True)

plt.figure(figsize = (10, 10))
plt.plot(new_data, np.exp(uncontam_logden_vals), color = 'tab:blue', lw = 3.0)
plt.hist(data_waiting, bins='fd', density = True, alpha = 0.3, color = 'tab:green')
plt.show()

file_name_newdata = f'/new_data.npy'
np.save(full_save_folder + file_name_newdata, new_data)

file_name_coef = f'/seed={seed_num}-folds={k_folds}-CV-uncontam-coef.npy'
np.save(full_save_folder + file_name_coef, coef_uncontam)

file_name_diff = f'/seed={seed_num}-folds={k_folds}-CV-uncontam-logden-newdata.npy'
np.save(full_save_folder + file_name_diff, uncontam_logden_vals)

print(f'uncontam_norm = {uncontam_norm}')
# Out:
# **************************************************
# log penalty = -10.0
# **************************************************
# log penalty = -9.5
# **************************************************
# log penalty = -9.0
# **************************************************
# log penalty = -8.5
# **************************************************
# log penalty = -8.0
# **************************************************
# log penalty = -7.5
# **************************************************
# log penalty = -7.0
# **************************************************
# log penalty = -6.5
# **************************************************
# log penalty = -6.0
# **************************************************
# log penalty = -5.5
# scores with no contamination: [-0.00812916 -0.00844537 -0.00857756 -0.00851753 -0.00830978 -0.00801798
#  -0.00768489 -0.00729001 -0.00674359 -0.00595566]
# --------------------------------------------------
# The optimal penalty parameter without contamination is -9.0.
# uncontam_norm = 5.751449616547219

# %%
# compute the cross-validated density estimator under F_{n+1}
r1, r2, c = 1., 0., 0.

result1 = []

N = data_waiting.shape[0]

for contam_data1 in contam_data_list: 
    
    print(f'start time = {dt.now().strftime("%H:%M:%S")}')
    
    j = 0
    sm_scores_contam = np.zeros((len(log_pen_param_list),), dtype = np.float64)
    
    print('=' * 80)
    print(f'contam data = {contam_data1.item()}')
    
    data_waiting2 = np.append(data_waiting, contam_data1.item())

    for log_pen_param in log_pen_param_list:
        
        print(f'log penalty = {log_pen_param}')

        grid_points = np.arange(1., 202., 1).reshape(-1, 1)
        
        # cross validation 
        np.random.seed(seed_num)
        folds_i = np.random.randint(low = 0, high=k_folds, size = N + 1)

        score_contam = 0.

        for i in range(k_folds):

            # data split
            train_data = data_waiting2[folds_i != i, ]
            test_data = data_waiting2[folds_i == i, ]

            # ------------------------------------------------------------
            # contaminated data 
            contam_sm = ContamSMFinKernelExpFam(
                data=train_data,
                contam_data=contam_data_list[0].reshape(-1, 1),
                grid_points=grid_points,
                contam_weight=0.,
                penalty_param=np.exp(log_pen_param),
                base_density=base_density,
                r1=r1,
                r2=r2,
                c=c,
                bw=bw,
                kernel_type='gaussian_poly2')

            coef_contam = contam_sm.coef()

            # evaluate the score matching loss function
            kernel_function_test = GaussianPoly2(
                data=test_data,
                r1=r1,
                r2=r2,
                c=c,
                bw=bw)

            matg = kernel_function_test.partial_kernel_matrix_10(grid_points).T

            t_vec = hatz(
                data=test_data,
                new_data=grid_points,
                kernel_function=kernel_function_test,
                base_density=base_density
            ).reshape(-1, 1)

            loss2 = coef_contam.T @ (matg @ matg.T / len(test_data)) @ coef_contam / 2. - coef_contam.T @ t_vec

            score_contam += loss2.item()

        sm_scores_contam[j, ] = score_contam / k_folds
        j += 1
        
    # print(f'scores with contamination: {sm_scores_contam}')

    print('-' * 50)

    # find the optimal regularization parameter
    opt_loglambda_contam = log_pen_param_list[np.argmin(sm_scores_contam)]
    
    print("The optimal penalty parameter with contamination {l1} is {l2}.".format(
        l1 = contam_data1.item(), l2 = opt_loglambda_contam))

    # run with all data 
    # contaminated data 
    contam_sm = ContamSMFinKernelExpFam(
        data=data_waiting2,
        contam_data=contam_data_list[0].reshape(-1, 1),
        grid_points=grid_points,
        contam_weight=0.,
        penalty_param=np.exp(opt_loglambda_contam),
        base_density=base_density,
        r1=r1,
        r2=r2,
        c=c,
        bw=bw,
        kernel_type='gaussian_poly2')

    coef_contam = contam_sm.coef()

    gram_mat = contam_sm.gram_matrix
    contam_norm = np.sqrt(coef_contam.T @ gram_mat @ coef_contam).item()
    contam_logden_vals = contam_sm.log_density(new_data, coef_contam, True)

    plt.figure(figsize = (8, 8))
    plt.plot(new_data, np.exp(contam_logden_vals), color = 'tab:blue', lw = 3.0)
    plt.hist(data_waiting2, bins='fd', density = True, alpha = 0.3, color = 'tab:green')
    plt.axvline(x = contam_data1.item(), color = 'k', linestyle='--')
    plt.show()
    
    IF_vals = (contam_logden_vals - uncontam_logden_vals) * (N + 1)

    plt.figure(figsize = (8, 8))
    plt.plot(new_data, IF_vals, color = 'tab:blue', lw = 3.0)
    plt.axvline(x = contam_data1.item(), color = 'k', linestyle='--')
    plt.show()

    file_name_coef = f'/seed={seed_num}-folds={k_folds}-contamdata={contam_data1.item()}-CV-contam-coef.npy'
    np.save(full_save_folder + file_name_coef, coef_contam)

    file_name_diff = f'/seed={seed_num}-folds={k_folds}-contamdata={contam_data1.item()}-CV-contam-logden-newdata.npy'
    np.save(full_save_folder + file_name_diff, contam_logden_vals)
    
    file_name_IF = f'/seed={seed_num}-folds={k_folds}-contamdata={contam_data1.item()}-CV-contam-IFvals-newdata.npy'
    np.save(full_save_folder + file_name_IF, IF_vals)
    
    result1.append([seed_num, contam_data1.item(), opt_loglambda_uncontam, uncontam_norm, 
                    opt_loglambda_contam, contam_norm, np.max(IF_vals), np.max(np.abs(IF_vals))])
    
    print(f'end time = {dt.now().strftime("%H:%M:%S")}')
# Out:
# start time = 22:53:09
# ================================================================================
# contam data = 20.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 20.0 is -9.0.
# end time = 22:53:49
# start time = 22:53:49
# ================================================================================
# contam data = 22.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 22.0 is -9.0.
# end time = 22:54:30
# start time = 22:54:30
# ================================================================================
# contam data = 24.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 24.0 is -9.0.
# end time = 22:55:11
# start time = 22:55:11
# ================================================================================
# contam data = 26.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 26.0 is -9.0.
# end time = 22:55:52
# start time = 22:55:52
# ================================================================================
# contam data = 28.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 28.0 is -9.0.
# end time = 22:56:34
# start time = 22:56:34
# ================================================================================
# contam data = 30.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 30.0 is -9.0.
# end time = 22:57:14
# start time = 22:57:14
# ================================================================================
# contam data = 32.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 32.0 is -8.5.
# end time = 22:57:55
# start time = 22:57:55
# ================================================================================
# contam data = 34.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 34.0 is -8.5.
# end time = 22:58:36
# start time = 22:58:36
# ================================================================================
# contam data = 36.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 36.0 is -9.0.
# end time = 22:59:17
# start time = 22:59:17
# ================================================================================
# contam data = 38.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 38.0 is -9.0.
# end time = 22:59:58
# start time = 22:59:58
# ================================================================================
# contam data = 40.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 40.0 is -9.0.
# end time = 23:00:39
# start time = 23:00:39
# ================================================================================
# contam data = 42.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 42.0 is -9.0.
# end time = 23:01:19
# start time = 23:01:19
# ================================================================================
# contam data = 44.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 44.0 is -8.5.
# end time = 23:02:00
# start time = 23:02:00
# ================================================================================
# contam data = 46.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 46.0 is -8.0.
# end time = 23:02:41
# start time = 23:02:41
# ================================================================================
# contam data = 48.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 48.0 is -9.0.
# end time = 23:03:22
# start time = 23:03:22
# ================================================================================
# contam data = 50.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 50.0 is -9.0.
# end time = 23:04:03
# start time = 23:04:03
# ================================================================================
# contam data = 52.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 52.0 is -9.0.
# end time = 23:04:44
# start time = 23:04:44
# ================================================================================
# contam data = 54.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 54.0 is -9.0.
# end time = 23:05:25
# start time = 23:05:25
# ================================================================================
# contam data = 56.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 56.0 is -9.0.
# end time = 23:06:06
# start time = 23:06:06
# ================================================================================
# contam data = 58.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 58.0 is -9.0.
# end time = 23:06:48
# start time = 23:06:48
# ================================================================================
# contam data = 60.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 60.0 is -9.0.
# end time = 23:07:29
# start time = 23:07:29
# ================================================================================
# contam data = 62.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 62.0 is -9.0.
# end time = 23:08:10
# start time = 23:08:10
# ================================================================================
# contam data = 64.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 64.0 is -9.0.
# end time = 23:08:51
# start time = 23:08:51
# ================================================================================
# contam data = 66.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 66.0 is -9.0.
# end time = 23:09:31
# start time = 23:09:31
# ================================================================================
# contam data = 68.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 68.0 is -9.0.
# end time = 23:10:12
# start time = 23:10:12
# ================================================================================
# contam data = 70.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 70.0 is -9.0.
# end time = 23:10:53
# start time = 23:10:53
# ================================================================================
# contam data = 72.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 72.0 is -9.0.
# end time = 23:11:34
# start time = 23:11:34
# ================================================================================
# contam data = 74.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 74.0 is -9.0.
# end time = 23:12:15
# start time = 23:12:15
# ================================================================================
# contam data = 76.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 76.0 is -9.0.
# end time = 23:12:56
# start time = 23:12:56
# ================================================================================
# contam data = 78.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 78.0 is -9.0.
# end time = 23:13:38
# start time = 23:13:38
# ================================================================================
# contam data = 80.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 80.0 is -9.0.
# end time = 23:14:19
# start time = 23:14:19
# ================================================================================
# contam data = 82.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 82.0 is -9.0.
# end time = 23:15:01
# start time = 23:15:01
# ================================================================================
# contam data = 84.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 84.0 is -9.0.
# end time = 23:15:42
# start time = 23:15:42
# ================================================================================
# contam data = 86.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 86.0 is -9.0.
# end time = 23:16:24
# start time = 23:16:24
# ================================================================================
# contam data = 88.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 88.0 is -9.0.
# end time = 23:17:04
# start time = 23:17:04
# ================================================================================
# contam data = 90.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 90.0 is -9.0.
# end time = 23:17:45
# start time = 23:17:45
# ================================================================================
# contam data = 92.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 92.0 is -8.5.
# end time = 23:18:27
# start time = 23:18:27
# ================================================================================
# contam data = 94.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 94.0 is -8.5.
# end time = 23:19:08
# start time = 23:19:08
# ================================================================================
# contam data = 96.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 96.0 is -9.5.
# end time = 23:19:50
# start time = 23:19:50
# ================================================================================
# contam data = 98.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 98.0 is -10.0.
# end time = 23:20:32
# start time = 23:20:32
# ================================================================================
# contam data = 100.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 100.0 is -9.5.
# end time = 23:21:13
# start time = 23:21:13
# ================================================================================
# contam data = 102.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 102.0 is -9.5.
# end time = 23:21:54
# start time = 23:21:54
# ================================================================================
# contam data = 104.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 104.0 is -9.0.
# end time = 23:22:35
# start time = 23:22:35
# ================================================================================
# contam data = 106.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 106.0 is -9.0.
# end time = 23:23:17
# start time = 23:23:17
# ================================================================================
# contam data = 108.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 108.0 is -8.5.
# end time = 23:23:58
# start time = 23:23:58
# ================================================================================
# contam data = 110.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 110.0 is -9.0.
# end time = 23:24:40
# start time = 23:24:40
# ================================================================================
# contam data = 112.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 112.0 is -9.0.
# end time = 23:25:21
# start time = 23:25:21
# ================================================================================
# contam data = 114.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 114.0 is -9.0.
# end time = 23:26:01
# start time = 23:26:01
# ================================================================================
# contam data = 116.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 116.0 is -9.0.
# end time = 23:26:43
# start time = 23:26:43
# ================================================================================
# contam data = 118.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 118.0 is -9.0.
# end time = 23:27:25
# start time = 23:27:25
# ================================================================================
# contam data = 120.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 120.0 is -9.0.
# end time = 23:28:06
# start time = 23:28:06
# ================================================================================
# contam data = 122.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 122.0 is -9.0.
# end time = 23:28:47
# start time = 23:28:47
# ================================================================================
# contam data = 124.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 124.0 is -9.0.
# end time = 23:29:29
# start time = 23:29:29
# ================================================================================
# contam data = 126.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 126.0 is -9.0.
# end time = 23:30:10
# start time = 23:30:10
# ================================================================================
# contam data = 128.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 128.0 is -9.0.
# end time = 23:30:52
# start time = 23:30:52
# ================================================================================
# contam data = 130.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 130.0 is -9.0.
# end time = 23:31:33
# start time = 23:31:33
# ================================================================================
# contam data = 132.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 132.0 is -9.0.
# end time = 23:32:15
# start time = 23:32:15
# ================================================================================
# contam data = 134.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 134.0 is -9.0.
# end time = 23:32:57
# start time = 23:32:57
# ================================================================================
# contam data = 136.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 136.0 is -9.0.
# end time = 23:33:39
# start time = 23:33:39
# ================================================================================
# contam data = 138.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 138.0 is -9.0.
# end time = 23:34:20
# start time = 23:34:20
# ================================================================================
# contam data = 140.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 140.0 is -9.0.
# end time = 23:35:02
# start time = 23:35:02
# ================================================================================
# contam data = 142.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 142.0 is -9.0.
# end time = 23:35:44
# start time = 23:35:44
# ================================================================================
# contam data = 144.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 144.0 is -9.0.
# end time = 23:36:26
# start time = 23:36:26
# ================================================================================
# contam data = 146.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 146.0 is -9.0.
# end time = 23:37:07
# start time = 23:37:07
# ================================================================================
# contam data = 148.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 148.0 is -9.0.
# end time = 23:37:48
# start time = 23:37:48
# ================================================================================
# contam data = 150.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 150.0 is -9.0.
# end time = 23:38:30
# start time = 23:38:30
# ================================================================================
# contam data = 152.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 152.0 is -9.0.
# end time = 23:39:12
# start time = 23:39:12
# ================================================================================
# contam data = 154.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 154.0 is -9.0.
# end time = 23:39:53
# start time = 23:39:53
# ================================================================================
# contam data = 156.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 156.0 is -9.0.
# end time = 23:40:36
# start time = 23:40:36
# ================================================================================
# contam data = 158.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 158.0 is -9.0.
# end time = 23:41:17
# start time = 23:41:17
# ================================================================================
# contam data = 160.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 160.0 is -9.0.
# end time = 23:41:58
# start time = 23:41:58
# ================================================================================
# contam data = 162.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 162.0 is -9.0.
# end time = 23:42:39
# start time = 23:42:39
# ================================================================================
# contam data = 164.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 164.0 is -9.0.
# end time = 23:43:21
# start time = 23:43:21
# ================================================================================
# contam data = 166.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 166.0 is -9.0.
# end time = 23:44:02
# start time = 23:44:02
# ================================================================================
# contam data = 168.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 168.0 is -9.0.
# end time = 23:44:44
# start time = 23:44:44
# ================================================================================
# contam data = 170.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 170.0 is -9.0.
# end time = 23:45:25
# start time = 23:45:25
# ================================================================================
# contam data = 172.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 172.0 is -9.0.
# end time = 23:46:06
# start time = 23:46:06
# ================================================================================
# contam data = 174.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 174.0 is -9.0.
# end time = 23:46:47
# start time = 23:46:47
# ================================================================================
# contam data = 176.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 176.0 is -9.0.
# end time = 23:47:28
# start time = 23:47:28
# ================================================================================
# contam data = 178.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5
# --------------------------------------------------
# The optimal penalty parameter with contamination 178.0 is -9.0.
# end time = 23:48:08
# start time = 23:48:08
# ================================================================================
# contam data = 180.0
# log penalty = -10.0
# log penalty = -9.5
# log penalty = -9.0
# log penalty = -8.5
# log penalty = -8.0
# log penalty = -7.5
# log penalty = -7.0
# log penalty = -6.5
# log penalty = -6.0
# log penalty = -5.5

# %%
pd.DataFrame(result1, columns = ['seed_num', 'contam_data', 'opt_loglambda_uncontam', 'uncontam_norm', 
                                 'opt_loglambda_contam', 'contam_norm', 'IF_sup_pos', 'IF_sup']).to_csv(
    f'/Users/chenxizhou/Desktop/seed-{seed_num}-fold-{k_folds}.csv')

# %% [markdown]
# ## Make plots

# %%
# cv_summary_folder = full_save_folder + '/data-summary-files'
# final_df = pd.DataFrame({})

# seed_num_list = [893371436, # 1405289136,  
#                  221902869, 2241142843,  354926085, 
#                  2368900135, 2773632455, 2723165907,  572329693, 3793478080,
#                  1238921510,  234059118, 2664351965,  655848720, 3958505628,
#                  3332268999, 1191655600,  818578564,  401340103, 1, 
#                  170, 644, 429, 948, 111, 362, 259, 652, 29, 178]

# k_folds = 10

# for seed_num in seed_num_list: 
    
#     temp = pd.read_csv(cv_summary_folder + f'/seed-{seed_num}-fold-{k_folds}.csv', 
#                        usecols = ['seed_num', 'contam_data', 'opt_loglambda_uncontam', 'uncontam_norm', 
#                                  'opt_loglambda_contam', 'contam_norm', 'IF_sup_pos', 'IF_sup'])
#     final_df = pd.concat([final_df, temp], axis = 0)

# %%
# final_df3 = final_df

# %%
# final_df5 = final_df

# %%
# final_df10 = final_df

# %%
# info_coord = (0.035, 0.035)
# horizontalalignment, verticalalignment = 'left', 'top'

# label_fontsize = 30
# info_fontsize = 35
# tick_fontsize = 22
# legend_fontsize = 25
# linewidth = 4.0
# x_label = r'$y$'
# y_label = r'overall influence'

# nrows = 1
# ncols = 3

# xlim = (15., 155.)
# ylim = (-50., 1110.)

# info_coord = (0.98, 0.98)

# fig = plt.figure(figsize=(30, 10))
# gs = gridspec.GridSpec(nrows = nrows, ncols = ncols)

# color = 'green'

# xticks = [25, 50, 75, 100, 125, 150]
# yticks = [0, 200, 400, 600, 800, 1000, 1200]

# contam_data_list = np.arange(20, 152, 2)

# # 3 fold
# ax1 = fig.add_subplot(gs[0, 0])

# df = final_df3
# plot_data = [df[df.contam_data == contam_data].IF_sup.to_list() for contam_data in contam_data_list.flatten()]

# ax1.boxplot(plot_data, 0, 'k.', 
#            widths = 1., 
#            positions = contam_data_list)

# ax1.set_xlim(xlim)
# ax1.set_ylim(ylim)

# ax1.set_xticks(xticks)
# ax1.set_xticklabels(xticks, size = tick_fontsize)

# ax1.set_xlabel(x_label, fontsize = label_fontsize)
# ax1.set_ylabel(y_label, fontsize = label_fontsize)
# ax1.tick_params(axis = 'both', labelsize = tick_fontsize)
# sns.rugplot(pd.Series(data_waiting.flatten()), ax = ax1, color = 'black')

# info = 'Fold number = 3'
# ax1.text(*info_coord,
#         info,
#         fontsize = info_fontsize,
#         multialignment = 'left',
#         horizontalalignment = 'right',
#         verticalalignment = 'top',
#         transform = ax1.transAxes,
#         bbox = {'facecolor': 'none',
#                 'boxstyle': 'Round, pad=0.2'})

# # 5 fold
# ax = fig.add_subplot(gs[0, 1], sharey = ax1)

# df = final_df5
# plot_data = [df[df.contam_data == contam_data].IF_sup.to_list() for contam_data in contam_data_list.flatten()]

# ax.boxplot(plot_data, 0, 'k.', 
#            widths = 1., 
#            positions = contam_data_list)

# ax.set_xlim(xlim)
# ax.set_yticks(yticks)
# ax.set_yticklabels(yticks, size = tick_fontsize)

# ax.set_xticks(xticks)
# ax.set_xticklabels(xticks, size = tick_fontsize)

# ax.set_xlabel(x_label, fontsize = label_fontsize)
# # ax.set_ylabel(y_label, fontsize = label_fontsize)

# plt.setp(ax.get_yticklabels(), visible=False)

# ax.tick_params(axis = 'x', labelsize = tick_fontsize)
# sns.rugplot(pd.Series(data_waiting.flatten()), ax = ax, color = 'black')

# info = 'Fold number = 5'
# ax.text(*info_coord,
#         info,
#         fontsize = info_fontsize,
#         multialignment = 'left',
#         horizontalalignment = 'right',
#         verticalalignment = 'top',
#         transform = ax.transAxes,
#         bbox = {'facecolor': 'none',
#                 'boxstyle': 'Round, pad=0.2'})

# # 10 fold
# ax = fig.add_subplot(gs[0, 2], sharey = ax1)

# df = final_df10
# plot_data = [df[df.contam_data == contam_data].IF_sup.to_list() for contam_data in contam_data_list.flatten()]

# ax.boxplot(plot_data, 0, 'k.', 
#            widths = 1., 
#            positions = contam_data_list)

# ax.set_xlim(xlim)
# ax.set_xticks(xticks)
# ax.set_xticklabels(xticks, size = tick_fontsize)

# plt.setp(ax.get_yticklabels(), visible=False)

# ax.set_xlabel(x_label, fontsize = label_fontsize)
# # ax.set_ylabel(y_label, fontsize = label_fontsize)
# ax.tick_params(axis = 'both', labelsize = tick_fontsize)
# sns.rugplot(pd.Series(data_waiting.flatten()), ax = ax, color = 'black')

# info = 'Fold number = 10'
# ax.text(*info_coord,
#         info,
#         fontsize = info_fontsize,
#         multialignment = 'left',
#         horizontalalignment = 'right',
#         verticalalignment = 'top',
#         transform = ax.transAxes,
#         bbox = {'facecolor': 'none',
#                 'boxstyle': 'Round, pad=0.2'})

# plt.tight_layout()

# # plt.savefig(f'plots/PenSMFin-geyser-waiting-overall-emp-influence-y-baseden=Gamma-26-3-gridpoints=1-202-1-cross-validation.pdf', 
# #             bbox_inches = 'tight')

# plt.show()
